# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeekamanickam/python/blob/main/numpy_series1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
lst = [ 1,2,3,4]
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
print( '1d array')
a=np.array([1,2,4,5])
print(a)
# Out:
# 1d array
# [1 2 4 5]

# %%
print( '2d array')
b= np.array([[1,23,34,5],[1,2,3,4]])
print(b)
# Out:
# 2d array
# [[ 1 23 34  5]
#  [ 1  2  3  4]]

# %%
print( '3d array')
c= np.array([[1,23,34,5],[1,2,3,4],[5,6,7,8]])
print(c)
# Out:
# 3d array
# [[ 1 23 34  5]
#  [ 1  2  3  4]
#  [ 5  6  7  8]]

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# ## size = tells the number of elements in an array
# arr.size

# %%
print(a.size)
print(b.size)
print(c.size)
# Out:
# 4
# 8
# 12

# %% [markdown]
# # shape =(rows,col)

# %%
print(a.shape)
print(b.shape)
print(c.shape)
# Out:
# (4,)
# (2, 4)
# (3, 4)

# %% [markdown]
# ## dtype = type of data present in that array
#
# ## arr.dtype

# %%
d=np.array([[1,2,4.2,5],[1,23,34,5],[1,2,3,4],[5,6,7,8]])

print(d)
print(d.shape)
print(d.dtype)
# Out:
# [[ 1.   2.   4.2  5. ]
#  [ 1.  23.  34.   5. ]
#  [ 1.   2.   3.   4. ]
#  [ 5.   6.   7.   8. ]]
# (4, 4)
# float64

# %%
print(d.transpose())
# Out:
# [[ 1.   1.   1.   5. ]
#  [ 2.  23.   2.   6. ]
#  [ 4.2 34.   3.   7. ]
#  [ 5.   5.   4.   8. ]]
